# %%
# Import opencv for computer vision stuff
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt

# %%
# Connect to capture device
cap = cv2.VideoCapture(0)
# Get a frame from the capture device
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Live Rendering from Webcam
# ---

# %%
# Import opencv for computer vision stuff
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt
# Connect to webcam
cap = cv2.VideoCapture(0)
# cap.set(3,1280)
# cap.set(4,720)
# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

# %% [markdown]
# Live Rendering with Predictions
# ---

# %%
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt
from ultralytics import YOLO
# Connect to webcam
cap = cv2.VideoCapture(0)

# Set the desired width and height
desired_width = 640
desired_height = 480
model=YOLO('last.pt')
# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results=model(frame,stream=True)
    for r in results:
        boxes=r.boxes
        for box in boxes:
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2)
            cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,255),3)
    
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 palm, 63.8ms
# Speed: 4.0ms preprocess, 63.8ms inference, 129.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 44.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0 35 274 411
# 0 5 282 402
# 0 28 263 412
# 0 32 262 413
# 0: 480x640 1 palm, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 9.0ms
# ...

# %% [markdown]
# Predictions on Video Input
# ---

# %%
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt
from ultralytics import YOLO
# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model=YOLO('pothole800.pt')
# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results=model(frame,stream=True)
    for r in results:
        boxes=r.boxes
        for box in boxes:
            class_name=int(box.cls[0])
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2,int(box.cls[0]))
            cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,255),3)
    
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()
# Out:
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# 141 168 430 208 1
# 553 163 609 183 0
# 137 169 430 211 1
# 556 165 612 186 0
# 134 171 433 213 1
# 558 165 613 187 0
# 132 172 433 213 1
# 559 166 616 188 0
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %%
import cv2
from matplotlib import pyplot as plt
from ultralytics import YOLO

# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 640
desired_height = 480
model=YOLO('pothole800.pt')

# Define colors for different classes
colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255), (255, 0, 255)]

# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results=model(frame,stream=True)
    for r in results:
        boxes=r.boxes
        for box in boxes:
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2)
            # Use the class id to get the color
            color = colors[box.class_id % len(colors)]
            cv2.rectangle(frame,(x1,y1),(x2,y2),color,3)
    
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()
# Out:
# 96 168 296 207
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24824\3895052707.py in <module>
#      29             print(x1,y1,x2,y2)
#      30             # Use the class id to get the color
# ---> 31             color = colors[box.class_id % len(colors)]
#      32             cv2.rectangle(frame,(x1,y1),(x2,y2),color,3)
#      33
#
# c:\Users\Public\anaconda3\lib\site-packages\ultralytics\utils\__init__.py in __getattr__(self, attr)
#     151         """Custom attribute access error message with helpful information."""
#     152         name = self.__class__.__name__
# --> 153         raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#     154
#     155
#
# AttributeError: 'Boxes' object has no attribute 'class_id'. See valid attributes below.
#
# ...

# %% [markdown]
# Creating Dataset
# ---

# %%
import cv2
import os

# Create the output folder if it doesn't exist
os.makedirs('output', exist_ok=True)

# Access the webcam
cap = cv2.VideoCapture(0)  # Adjust the index if needed

count = 0  # Image counter

while True:
    ret, frame = cap.read()

    cv2.imshow('Webcam', frame)

    # Capture photo on 'q' press
    if cv2.waitKey(1) & 0xFF == ord('p'):
        cv2.imwrite(os.path.join('output', f'photo_{count}.jpg'), frame)
        count += 1
        print('Photo captured and saved!')

    # Exit on 'q' press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import torch
import cv2
from ultralytics import YOLO
model=YOLO('last.pt')
img='2.jpg'
results=model(img)
for result in results:
    print(f"Detected object: {result['name']} at {result['box']}")

# If you want to draw the bounding boxes on the image and save it, you'll need to use a library 
# like OpenCV or PIL. Here's an example using PIL:

# Load the image
image = Image.open(img)

# Create a drawing context
draw = ImageDraw.Draw(image)

# Draw each bounding box
for result in results:
    box = result['box']
    draw.rectangle([(box[0], box[1]), (box[2], box[3])], outline="red")

# Save the image
image.save("output.jpg")
# Out:
# image 1/1 c:\Users\Mahin Prakash\Desktop\DS\CV\2.jpg: 384x640 1 palm, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23520\3591406300.py in <module>
#       6 results=model(img)
#       7 for result in results:
# ----> 8     print(f"Detected object: {result['name']} at {result['box']}")
#       9
#      10 # If you want to draw the bounding boxes on the image and save it, you'll need to use a library
#
# c:\Users\Public\anaconda3\lib\site-packages\ultralytics\engine\results.py in __getitem__(self, idx)
#     106     def __getitem__(self, idx):
#     107         """Return a Results object for the specified index."""
# --> 108         return self._apply('__getitem__', idx)
#     109
#     110     def __len__(self):
#
# ...

# %%
import torch
from PIL import Image, ImageDraw
from ultralytics import YOLO

# Load the model
model = YOLO('last.pt')

# Specify the image
img = '2.jpg'

# Perform object detection
results = model(img)

# Print detected objects
df = results.pandas().xyxy[0]  # Get detections dataframe
for index, row in df.iterrows():
    print(f"Detected object: {row['name']} at {row[['xmin', 'ymin', 'xmax', 'ymax']]}")

# Load the image
image = Image.open(img)

# Create a drawing context
draw = ImageDraw.Draw(image)

# Draw each bounding box
for index, row in df.iterrows():
    box = row[['xmin', 'ymin', 'xmax', 'ymax']]
    draw.rectangle([(box['xmin'], box['ymin']), (box['xmax'], box['ymax'])], outline="red")

# Save the image
image.save("output.jpg")
# Out:
# image 1/1 c:\Users\Mahin Prakash\Desktop\DS\CV\2.jpg: 384x640 1 palm, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23520\3789318957.py in <module>
#      13
#      14 # Print detected objects
# ---> 15 df = results.pandas().xyxy[0]  # Get detections dataframe
#      16 for index, row in df.iterrows():
#      17     print(f"Detected object: {row['name']} at {row[['xmin', 'ymin', 'xmax', 'ymax']]}")
#
# AttributeError: 'list' object has no attribute 'pandas'

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
plt. imshow(np.squeeze(results.render()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23520\4142927336.py in <module>
#       2 from matplotlib import pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 plt. imshow(np.squeeze(results.render()))
#       5 plt.show()
#
# AttributeError: 'list' object has no attribute 'render'

# %%
from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('last.pt')

# Run inference on 'bus.jpg'
results = model('1.jpg')  # results list

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results1.jpg')  # save image
# Out:
# image 1/1 c:\Users\Mahin Prakash\Desktop\DS\CV\1.jpg: 384x640 1 palm, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('last.pt')

# Run inference on 'bus.jpg'
results = model('1.jpg')  # results list

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results1.jpg')  # save image

# Print the width and height of each bounding box
for r in results.xyxy[0]:  # for each detected object
    x1, y1, x2, y2, conf, cls = r.tolist()  # get bounding box coordinates and other info
    width = x2 - x1  # calculate width
    height = y2 - y1  # calculate height
    print(f"Width: {width}, Height: {height}")
# Out:
# image 1/1 c:\Users\Mahin Prakash\Desktop\DS\CV\1.jpg: 384x640 1 palm, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23520\764091101.py in <module>
#      16
#      17 # Print the width and height of each bounding box
# ---> 18 for r in results.xyxy[0]:  # for each detected object
#      19     x1, y1, x2, y2, conf, cls = r.tolist()  # get bounding box coordinates and other info
#      20     width = x2 - x1  # calculate width
#
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt
# Connect to webcam
cap = cv2.VideoCapture(0)

# Set the desired width and height
desired_width = 640
desired_height = 480

# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

# %% [markdown]
# Currently Working Model
# ---

# %%
import cv2
import math
from matplotlib import pyplot as plt
from ultralytics import YOLO
# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model=YOLO('pothole800.pt')
count_line_position=280
# Loop through every frame until we close our webcam
while cap.isOpened(): 
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results=model(frame,stream=True)
    for r in results:
        boxes=r.boxes
        cv2.line(frame,(5,count_line_position),(930,count_line_position),(0,0,255),3)
        for box in boxes:
            class_name=int(box.cls[0])
            box_color = (0, 255, 0)
            if(class_name==0 and (math.ceil((box.conf[0]*100))/100)>0.5):
                box_color = (0, 255, 0)
            elif(class_name==1 and (math.ceil((box.conf[0]*100))/100)>0.5):
                box_color = (255, 255, 0)
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2,int(box.cls[0]))
            cv2.rectangle(frame,(x1,y1),(x2,y2),box_color,3)
            
    # Show image 
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()
# Out:
# 0: 352x640 1 small, 1 medium, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 26.0ms
# 141 168 430 208 1
# 553 163 609 183 0
# 137 169 430 211 1
# 556 165 612 186 0
# 134 171 433 213 1
# 558 165 613 187 0
# 132 172 433 213 1
# 559 166 616 188 0
# 132 173 436 217 1
# 560 167 619 190 0
# Speed: 3.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 26.0ms
# ...

# %% [markdown]
# Latest
# ---

# %%
import cv2
import math
from ultralytics import YOLO

# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model = YOLO('pothole800.pt')
count_line_position = 280

# Initialize an empty list to store bounding box dimensions
bounding_box_dimensions = []

# Loop through every frame until we close our webcam
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results = model(frame, stream=True)
    for r in results:
        boxes = r.boxes
        cv2.line(frame, (5, count_line_position), (930, count_line_position), (0, 0, 255), 3)
        for box in boxes:
            class_name = int(box.cls[0])
            box_color = (0, 255, 0)
            if class_name == 0 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (0, 255, 0)
            elif class_name == 1 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (255, 255, 0)
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 3)
            
            # Check if the box intersects the line
            if y1 <= count_line_position <= y2:
                bounding_box_dimensions.append((x1, y1, x2 - x1, y2 - y1))

    # Show image
    cv2.imshow('Webcam', frame)

    # Checks whether 'q' has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

# Print the bounding box dimensions that intersected the line
print("Bounding box dimensions touching the line:")
for bbox in bounding_box_dimensions:
    print(f"X: {bbox[0]}, Y: {bbox[1]}, Width: {bbox[2]}, Height: {bbox[3]}")
# Out:
# 0: 352x640 1 small, 1 medium, 29.0ms
# Speed: 5.0ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %%
import cv2
import math
from ultralytics import YOLO

# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model = YOLO('pothole800.pt')
count_line_position = 280

# Initialize a dictionary to store bounding box dimensions for each object
object_bboxes = {}

# Loop through every frame until we close our webcam
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results = model(frame, stream=True)
    for r in results:
        boxes = r.boxes
        cv2.line(frame, (5, count_line_position), (930, count_line_position), (0, 0, 255), 3)
        for box in boxes:
            class_name = int(box.cls[0])
            box_color = (0, 255, 0)
            if class_name == 0 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (0, 255, 0)
            elif class_name == 1 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (255, 255, 0)
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 3)
            
            # Check if the box intersects the line
            if y1 <= count_line_position <= y2:
                # Create a unique identifier for each object (e.g., class name + box coordinates)
                obj_id = f"{class_name}_{x1}_{y1}_{x2}_{y2}"
                if obj_id not in object_bboxes:
                    object_bboxes[obj_id] = (x1, y1, x2 - x1, y2 - y1)

    # Show image
    cv2.imshow('Webcam', frame)

    # Checks whether 'q' has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

# Print the bounding box dimensions for each unique object
print("Bounding box dimensions touching the line:")
for obj_id, bbox in object_bboxes.items():
    print(f"Object ID: {obj_id}, Dimensions: X: {bbox[0]}, Y: {bbox[1]}, Width: {bbox[2]}, Height: {bbox[3]}")
# Out:
# 0: 352x640 1 small, 1 medium, 28.0ms
# Speed: 4.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 28.0ms
# Speed: 5.0ms preprocess, 28.0ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 26.0ms
# Speed: 4.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %%
import cv2
import math
from ultralytics import YOLO

# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model = YOLO('pothole800.pt')
count_line_position = 280

# Initialize an empty list to store bounding box dimensions
bounding_box_dimensions = []

# Loop through every frame until we close our webcam
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results = model(frame, stream=True)
    for r in results:
        boxes = r.boxes
        cv2.line(frame, (5, count_line_position), (930, count_line_position), (0, 0, 255), 3)
        for box in boxes:
            class_name = int(box.cls[0])
            box_color = (0, 255, 0)
            if class_name == 0 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (0, 255, 0)
            elif class_name == 1 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (255, 255, 0)
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 3)
            
            # Check if the box intersects the line
            if x1 <= count_line_position <= x2:
                # Include class name in the bounding box dimensions
                bounding_box_dimensions.append((class_name, x1, y1, x2 - x1, y2 - y1))

    # Show image
    cv2.imshow('Webcam', frame)

    # Checks whether 'q' has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

print("Bounding box dimensions touching the line:")
for bbox in bounding_box_dimensions:
    print(f"Class: {bbox[0]}, X: {bbox[1]}, Y: {bbox[2]}, Width: {bbox[3]}, Height: {bbox[4]}")
len(bounding_box_dimensions)
# Out:
# 0: 352x640 1 small, 1 medium, 28.0ms
# Speed: 5.0ms preprocess, 28.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 small, 1 medium, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %% [markdown]
# Centroid Code
# ---

# %%
import cv2
import math
from ultralytics import YOLO

# Connect to webcam
cap = cv2.VideoCapture('upload_video.mp4')

# Set the desired width and height
desired_width = 940
desired_height = 480
model = YOLO('pothole1000.pt')
count_line_position = 280

# Initialize an empty list to store bounding box dimensions
bounding_box_dimensions = []
offset=3.5
# Loop through every frame until we close our webcam
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    # Resize the frame
    frame = cv2.resize(frame, (desired_width, desired_height))
    results = model(frame, stream=True)
    for r in results:
        boxes = r.boxes
        cv2.line(frame, (5, count_line_position), (930, count_line_position), (0, 0, 255), 3)
        for box in boxes:
            class_name = int(box.cls[0])
            box_color = (0, 255, 0)
            if class_name == 0 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (0, 255, 0)
            elif class_name == 1 and (math.ceil((box.conf[0] * 100)) / 100) > 0.5:
                box_color = (255, 255, 0)
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 3)
            if(class_name==0):
                name_class='small'
            else:
                name_class='medium'    
            cv2.putText(frame, name_class, (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 1.3, box_color, 3, cv2.LINE_AA)
            # Calculate the centroid of the bounding box
            centroid_x = x1 + (x2 - x1) // 2
            centroid_y = y1 + (y2 - y1) // 2
            
            # Draw a circle at the centroid
            cv2.circle(frame, (centroid_x, centroid_y), radius=5, color=(0, 0, 255), thickness=-1)
            
            # Check if the centroid intersects the line
            if centroid_y<(count_line_position+offset) and centroid_y>(count_line_position-offset):
                # Include class name in the bounding box dimensions
                #bounding_box_dimensions.append((class_name, x1, y1, x2 - x1, y2 - y1))
                bounding_box_dimensions.append((class_name,x2 - x1, y2 - y1))

    # Show image
    cv2.imshow('Webcam', frame)

    # Checks whether 'q' has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Releases the webcam
cap.release()
# Closes the frame
cv2.destroyAllWindows()

print("Bounding box dimensions touching the line:")
for bbox in bounding_box_dimensions:
    #print(f"Class: {bbox[0]}, X: {bbox[1]}, Y: {bbox[2]}, Width: {bbox[3]}, Height: {bbox[4]}")
    print(f"Class: {bbox[0]},Width: {bbox[1]}, Height: {bbox[2]}")
len(bounding_box_dimensions)
# Out:
# 0: 352x640 2 smalls, 1 medium, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 26.0ms
# Speed: 4.0ms preprocess, 26.0ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 smalls, 1 medium, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...
